# %% [markdown]
# <a href="https://colab.research.google.com/github/prgmr99/deep_learning-pytorch-/blob/others/pytorch_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **batch size** = 행의 크기
#
# **dim** = 열의 크기
#
#
# ---
#
# NLP(자연어 처리)는 보통 (batch size, 문장 길이, 단어 벡터의 차원)이라는 3차원 텐서를 사용
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 4x3x3의 크기를 가지는 3차원 텐서
#
# batch size를 2로 해보면 아래와 같다. 즉, 행을 2로 변경하는 것.
#
# ![image.png](data:image/png;base64,...)
